# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
titanic = sns.load_dataset('titanic')
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# # categorical graphs
# data is said to be categorical when the values of that set are less and specific e.g in titanic survived and pclass is categorical
# - columns that have text generally
# - first count unique values
# - plot the count of each category
# - following charts are a good way to visualiz data
#     - bar chart
#     - pie chart
#     - line chart
#     - donut chart
#     - area chart

# %%
print(titanic['survived'].unique())
print(titanic['pclass'].unique())
print(titanic['age'].unique())
# Out:
# [0 1]
# [3 1 2]
# [22.   38.   26.   35.     nan 54.    2.   27.   14.    4.   58.   20.
#  39.   55.   31.   34.   15.   28.    8.   19.   40.   66.   42.   21.
#  18.    3.    7.   49.   29.   65.   28.5   5.   11.   45.   17.   32.
#  16.   25.    0.83 30.   33.   23.   24.   46.   59.   71.   37.   47.
#  14.5  70.5  32.5  12.    9.   36.5  51.   55.5  40.5  44.    1.   61.
#  56.   50.   36.   45.5  20.5  62.   41.   52.   63.   23.5   0.92 43.
#  60.   10.   64.   13.   48.    0.75 53.   57.   80.   70.   24.5   6.
#   0.67 30.5   0.42 34.5  74.  ]

# %%
survival_count = titanic['survived'].value_counts()
pclass_k = titanic['pclass'].value_counts()
print(titanic['pclass'].value_counts())

survival_count.plot(kind='pie', autopct= '%.1f%%', title= 'survival rate')#ye shortcut hai plot karne ka isi ko use kare
# Out:
# pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64
# <Axes: title={'center': 'survival rate'}, ylabel='count'>

# %%
survival_count.plot(
    kind = 'pie',
    autopct = '%.1f%%',
    title = 'survival rate',
    labels= ['survived','not survived'],
    colors= ['#66b3ff','#ff9999'],
    labeldistance = 1.1,
    wedgeprops = {
       'width':0.5#agar donut banana hai to wedgeprop mei width humesha 0 se 1 ke "beech" mei rakho
    }
)
# Out:
# <Axes: title={'center': 'survival rate'}, ylabel='count'>

# %%
pclass_k.plot(
    kind = 'pie',
    autopct = '%.1f%%',
    title = 'number of ppl in deck x',
    labels= ['3','1','2'],
    colors= ['#66b3ff','#ff9999','#abc'],
    labeldistance = 1.1,
    wedgeprops = {
       'width':0.5#agar donut banana hai to wedgeprop mei width humesha 0 se 1 ke "beech" mei rakho
    }
)
# Out:
# <Axes: title={'center': 'number of ppl in deck x'}, ylabel='count'>

# %% [markdown]
# # seaborn
# - for complex data visualization using  simple code

# %%
sns.countplot(data = titanic, x ='alive', hue = 'sex')#hue grouping ke hisaab se graph banata hai
# Out:
# <Axes: xlabel='alive', ylabel='count'>

# %%
sns.jointplot(x = 'fare', y = 'age', data = titanic, kind = 'scatter', hue = 'survived')

# %%
print(sns.load_dataset("tips"))
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips = sns.load_dataset("tips")

# Create a visualization
sns.relplot(
    data=tips,
    x="total_bill", y="tip", col="time",
    hue="smoker", style="smoker", size="size",
)
# Out:
# c:\Users\raxriot\miniconda3\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
dots = sns.load_dataset("dots")#replot mei by default wo dots leta hai but agar tum uske andar kinde mei line daal doge to wo line lega
print (dots)
sns.relplot(
    data=dots, kind="line",
    x="time", y="firing_rate", col="align",
    hue="choice",size = "coherence", style="choice",
    facet_kws=dict(sharex=False),##it is used for making the graph look optimized
)
# Out:
#     align choice  time  coherence  firing_rate
# 0    dots     T1   -80        0.0    33.189967
# 1    dots     T1   -80        3.2    31.691726
# 2    dots     T1   -80        6.4    34.279840
# 3    dots     T1   -80       12.8    32.631874
# 4    dots     T1   -80       25.6    35.060487
# ..    ...    ...   ...        ...          ...
# 843  sacc     T2   300        3.2    33.281734
# 844  sacc     T2   300        6.4    27.583979
# 845  sacc     T2   300       12.8    28.511530
# 846  sacc     T2   300       25.6    27.009804
# 847  sacc     T2   300       51.2    30.959302
#
# [848 rows x 5 columns]
# c:\Users\raxriot\miniconda3\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
dots = sns.load_dataset('dots')#remember whenever we want to plot a graph tween time and variable value that is in proportionality with the time somehow,we use line 
print (dots)
# Out:
#     align choice  time  coherence  firing_rate
# 0    dots     T1   -80        0.0    33.189967
# 1    dots     T1   -80        3.2    31.691726
# 2    dots     T1   -80        6.4    34.279840
# 3    dots     T1   -80       12.8    32.631874
# 4    dots     T1   -80       25.6    35.060487
# ..    ...    ...   ...        ...          ...
# 843  sacc     T2   300        3.2    33.281734
# 844  sacc     T2   300        6.4    27.583979
# 845  sacc     T2   300       12.8    28.511530
# 846  sacc     T2   300       25.6    27.009804
# 847  sacc     T2   300       51.2    30.959302
#
# [848 rows x 5 columns]
